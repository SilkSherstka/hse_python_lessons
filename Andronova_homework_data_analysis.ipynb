# %% [markdown]
# <a href="https://colab.research.google.com/github/SilkSherstka/hse_python_lessons/blob/main/Andronova_homework_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1: выгрузка файлов

# %% [markdown]
# *1*. Зайдите в репозиторий датасетов для обучения диалоговых систем
# 2. Найдите все файлы с расширением *.txt (их всего 5 в репозитории)
# 3. Выгрузите каждый файл с помощью утилиты `wget`
# - Для этого откройте датасет в браузере, например, https://github.com/Phylliida/Dialogue-Datasets/blob/master/TwitterLowerAsciiCorpus.txt
# - Затем найдите кнопку `raw`, которая откроет вам файл "как есть" (как в блокноте!)
# - Скопируйте ссылку на файл (она выглядит так: https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt)
# - Воспользуйтесь `wget`
# ---
# Как использовать `wget`:
# ---

# %%
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt -O twitter.txt
# Out:
# --2025-12-02 20:25:29--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 593707 (580K) [text/plain]
# Saving to: ‘twitter.txt’
#
# twitter.txt         100%[===================>] 579.79K  --.-KB/s    in 0.04s
#
# 2025-12-02 20:25:30 (15.2 MB/s) - ‘twitter.txt’ saved [593707/593707]

# %% [markdown]
# Здесь:
# - ! указывает на то, что это консольная утилита, а не код на python
# - после wget идет полный адрес ссылки для скачивания файла
# - после параметра `-O` указываем название файла, под которым мы хотим скачать файл

# %%
# Ваш код здесь: повторите процедуру для остальных файлов (всего должно быть 5 файлов)
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCCorpus.txt -O twitter1.txt

# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCSplitWordsCorpus.txt -O twitter2.txt

# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/MovieCorpus.txt -O twitter3.txt

# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterConvCorpus.txt -O twitter4.txt
# Out:
# --2025-12-02 20:25:30--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19081694 (18M) [text/plain]
# Saving to: ‘twitter1.txt’
#
# twitter1.txt        100%[===================>]  18.20M  --.-KB/s    in 0.1s
#
# 2025-12-02 20:25:30 (167 MB/s) - ‘twitter1.txt’ saved [19081694/19081694]
#
# --2025-12-02 20:25:30--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCSplitWordsCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173003 (18M) [text/plain]
# Saving to: ‘twitter2.txt’
#
# twitter2.txt        100%[===================>]  18.28M  --.-KB/s    in 0.1s
#
# 2025-12-02 20:25:31 (156 MB/s) - ‘twitter2.txt’ saved [19173003/19173003]
#
# --2025-12-02 20:25:31--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/MovieCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16976724 (16M) [text/plain]
# Saving to: ‘twitter3.txt’
#
# twitter3.txt        100%[===================>]  16.19M  --.-KB/s    in 0.1s
#
# 2025-12-02 20:25:31 (142 MB/s) - ‘twitter3.txt’ saved [16976724/16976724]
#
# --2025-12-02 20:25:31--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterConvCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 612338 (598K) [text/plain]
# Saving to: ‘twitter4.txt’
#
# twitter4.txt        100%[===================>] 597.99K  --.-KB/s    in 0.04s
#
# 2025-12-02 20:25:31 (13.5 MB/s) - ‘twitter4.txt’ saved [612338/612338]

# %% [markdown]
# ## Задание 2: открываем файлы

# %% [markdown]
# Изучите туториал по работе с файлами, который вы получили в чате. Каждый файл нужно теперь открыть, а его содержание - записать в переменную *любым удобным вам способом*
#
# Пример:

# %%
# Открываем файл с указанием кодировки
file = open('twitter.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 593707 символов
# "what's up dadyo when did you get back on twitter? haha\nlike 2 weeks ago and it's going as terribly a"

# %%
# Ваш код здесь: откройте все файлы, выведите на экран их размер и первые 100 символов (всего должно быть обработано 5 файлов)

print("-----twitter1.txt-----")
file = open('twitter1.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
print(dataset_content[:100])

print("-----twitter2.txt-----")
file = open('twitter2.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
print(dataset_content[:100])

print("-----twitter3.txt-----")
file = open('twitter3.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
print(dataset_content[:100])

print("-----twitter4.txt-----")
file = open('twitter4.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
print(dataset_content[:100])
# Out:
# -----twitter1.txt-----
# Файл успешно загружен!
# Размер файла: 19081694 символов
# You enjoyed yourself in America
# Eh
# did you
# Oh I covered a nice tripyes
# Oh very good
# saw Mary and And
# -----twitter2.txt-----
# Файл успешно загружен!
# Размер файла: 19173003 символов
# You enjoyed yourself in America
# Eh
# did you
# Oh I covered a nice trip yes
# Oh very good
# saw Mary and An
# -----twitter3.txt-----
# Файл успешно загружен!
# Размер файла: 16976724 символов
# Colonel Durnford... William Vereker. I hear you 've been seeking Officers?
# Good ones, yes, Mr Vereke
# -----twitter4.txt-----
# Файл успешно загружен!
# Размер файла: 598556 символов
# what's up dadyo when did you get back on Twitter? Haha
# like 2 weeks ago and it's going as terribly a

# %% [markdown]
# ## Задание 3: первичный анализ

# %% [markdown]
# Выведем статистику для каждого файла по образцу:

# %%
# 1. Разбиваем содержание файла на строки
print("-----twitter1.txt-----")
file = open('twitter1.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

lines = list(dataset_content.split('\n'))
words = list(dataset_content.split(' '))
chars = list(dataset_content)

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = len(lines)         # общее количество строк
total_words = len(words)         # общее количество слов
total_chars = len(chars)         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)
for line in lines:
  if len(line) > 0:
    non_empty_lines=non_empty_lines+1


# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
for line in lines:
  if len(line) > max_line_length:
    max_line_length=len(line)

min_line_length = 0   # максимальная длина строки
for line in lines:
  if len(line) < min_line_length:
    min_line_length=len(line)

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")


# 1. Разбиваем содержание файла на строки
print("-----twitter2.txt-----")
file = open('twitter2.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

lines = list(dataset_content.split('\n'))
words = list(dataset_content.split(' '))
chars = list(dataset_content)

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = len(lines)         # общее количество строк
total_words = len(words)         # общее количество слов
total_chars = len(chars)         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)
for line in lines:
  if len(line) > 0:
    non_empty_lines=non_empty_lines+1


# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
for line in lines:
  if len(line) > max_line_length:
    max_line_length=len(line)

min_line_length = 0   # максимальная длина строки
for line in lines:
  if len(line) < min_line_length:
    min_line_length=len(line)

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")

# 1. Разбиваем содержание файла на строки
print("-----twitter3.txt-----")
file = open('twitter3.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

lines = list(dataset_content.split('\n'))
words = list(dataset_content.split(' '))
chars = list(dataset_content)

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = len(lines)         # общее количество строк
total_words = len(words)         # общее количество слов
total_chars = len(chars)         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)
for line in lines:
  if len(line) > 0:
    non_empty_lines=non_empty_lines+1


# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
for line in lines:
  if len(line) > max_line_length:
    max_line_length=len(line)

min_line_length = 0   # максимальная длина строки
for line in lines:
  if len(line) < min_line_length:
    min_line_length=len(line)

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")

# 1. Разбиваем содержание файла на строки
print("-----twitter4.txt-----")
file = open('twitter4.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

lines = list(dataset_content.split('\n'))
words = list(dataset_content.split(' '))
chars = list(dataset_content)

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = len(lines)         # общее количество строк
total_words = len(words)         # общее количество слов
total_chars = len(chars)         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)
for line in lines:
  if len(line) > 0:
    non_empty_lines=non_empty_lines+1


# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
for line in lines:
  if len(line) > max_line_length:
    max_line_length=len(line)

min_line_length = 0   # максимальная длина строки
for line in lines:
  if len(line) < min_line_length:
    min_line_length=len(line)

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# -----twitter1.txt-----
# Всего строк: 611015
# Непустых строк: 606486
# Всего слов: 3354447
# Всего символов: 19081694
# Макс. длина строки: 2702
# Мин. длина строки: 0
# -----twitter2.txt-----
# Всего строк: 611015
# Непустых строк: 606486
# Всего слов: 3445756
# Всего символов: 19173003
# Макс. длина строки: 2773
# Мин. длина строки: 0
# -----twitter3.txt-----
# Всего строк: 304714
# Непустых строк: 304713
# Всего слов: 2905854
# Всего символов: 16976724
# Макс. длина строки: 3039
# Мин. длина строки: 0
# -----twitter4.txt-----
# Всего строк: 16557
# Непустых строк: 10628
# Всего слов: 104508
# Всего символов: 598556
# Макс. длина строки: 146
# Мин. длина строки: 0

# %% [markdown]
# ## Задание 4: чистка текста

# %%
import re

cleaned_lines = [] # чистим текст построчно (сохраняем каждую очищенную строку в список)
all_cleaned_words = [] # также сохраняем все слова после очистки в список

# Ваш код здесь: реализуйте очистку с помощью цикла for и RegEx
for line in lines:
# 1. Используйте strip для удаления лишних пробелов из строки
  line = line.strip()
# 2. Очищаем строку: оставляем только буквы, цифры и пробелы
  line = re.sub(r'[^\w\s]', '', line)
# 3. Убираем лишние пробелы
  line = re.sub(r'\s+', ' ', line)
# 4. Приводим к нижнему регистру
  line = line.lower()
# 5. Собираем все слова после очистки в единый список
  cleaned_lines.append(line)
#    - не фиксируем слова короче 1 символа

for word in words:
  word = word.strip()
  word = re.sub(r'[^\w\s]', '', word)
  word = re.sub(r'\s+', ' ', word)
  word = word.lower()
  if len(word) > 1:
    all_cleaned_words.append(word)

# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words)}")
# Out:
# Пример очищенной строки: whats up dadyo when did you get back on twitter haha...
# Всего очищенных слов: 97778

# %% [markdown]
# ## Задание 5: статистика

# %% [markdown]
# Часть 1: получаем статистику распределений длин слов

# %%
# Статистика по очищенным данным
total_words = len(all_cleaned_words)
total_chars = 0
word_lengths = []

# Ваш код здесь: создайте список длин слов word_lengths
for word in all_cleaned_words:
  word_lengths.append(len(word))
#                и посчитайте общее количество символов total_chars
  total_chars += len(word)

# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count = {}
# Ваш код здесь: для каждого значения длины в списке word_lengths
for length in word_lengths:
#                если длина уже зафиксирована в word_length_count, то выполняем >
  if length in word_length_count:
        word_length_count[length] += 1
#                иначе: выполняем >
  else:
        word_length_count[length] = 1

# Ожидаемый результат:
print(f"Слов после очистки: {total_words}")
print(f"Символов после очистки: {total_chars}")
print("Распределение длин слов:")
for length in sorted(word_length_count.keys()):
    print(f"  {length} букв: {word_length_count[length]} слов")
# Out:
# Слов после очистки: 97778
# Символов после очистки: 455751
# Распределение длин слов:
#   2 букв: 17284 слов
#   3 букв: 20794 слов
#   4 букв: 21926 слов
#   5 букв: 11829 слов
#   6 букв: 7397 слов
#   7 букв: 6136 слов
#   8 букв: 4145 слов
#   9 букв: 2795 слов
#   10 букв: 1855 слов
#   11 букв: 1177 слов
#   12 букв: 790 слов
#   13 букв: 523 слов
#   14 букв: 369 слов
#   15 букв: 246 слов
#   16 букв: 140 слов
#   17 букв: 112 слов
#   18 букв: 81 слов
#   19 букв: 49 слов
#   20 букв: 39 слов
#   21 букв: 16 слов
#   22 букв: 22 слов
#   23 букв: 10 слов
#   24 букв: 11 слов
#   25 букв: 6 слов
#   26 букв: 4 слов
#   27 букв: 6 слов
#   28 букв: 4 слов
#   29 букв: 1 слов
#   31 букв: 1 слов
#   32 букв: 3 слов
#   34 букв: 2 слов
#   37 букв: 1 слов
#   39 букв: 1 слов
#   54 букв: 1 слов
#   61 букв: 1 слов
#   101 букв: 1 слов

# %% [markdown]
# Часть 2: частотность слов

# %%
# Считаем частотность слов (по аналогии с подсчетом word_length_count)
word_frequency = {}
# Ваш код здесь:
# проходим по all_cleaned_words
for word in all_cleaned_words:
# если слово зафиксировано в word_frequency, то
  if word in word_frequency:
        word_frequency[word] += 1
# иначе
  else:
        word_frequency[word] = 1

# Находим топ-10 самых частых слов
# Начинаем с формирования кортежей вида (частотность слова, лексема)
word_count_pairs = []
for word, count in word_frequency.items():
    word_count_pairs.append((count, word))

# Сортируем вручную через вложенные циклы
for i in range(len(word_count_pairs)):
    for j in range(i + 1, len(word_count_pairs)):
        if word_count_pairs[j][0] > word_count_pairs[i][0]:
            # Меняем местами
            temp = word_count_pairs[i]
            word_count_pairs[i] = word_count_pairs[j]
            word_count_pairs[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs))):
    count, word = word_count_pairs[i]
    print(f"  {i+1}. '{word}': {count} раз")
print(word_frequency)
# Ваш код здесь: создайте множество unique_words
unique_words = []
for words in all_cleaned_words:
  if words not in unique_words:
    unique_words.append(word)

print(f"\nВсего уникальных слов: {len(unique_words)}")
# Out:
# Топ-10 самых частых слов:
#   1. 'the': 2769 раз
#   2. 'to': 2543 раз
#   3. 'you': 1855 раз
#   4. 'and': 1575 раз
#   5. 'it': 1178 раз
#   6. 'in': 1124 раз
#   7. 'my': 1085 раз
#   8. 'of': 1068 раз
#   9. 'is': 1026 раз
#   10. 'that': 1020 раз
# {'whats': 34, 'up': 483, 'dadyo': 1, 'when': 282, 'did': 185, 'you': 1855, 'get': 483, 'back': 166, 'on': 793, 'twitter': 44, 'haha like': 1, 'weeks': 21, 'ago': 34, 'and': 1575, 'its': 479, 'going': 202, 'as': 280, 'terribly': 1, 'remember': 43, 'but': 766, 'deg': 1, 'is': 1026, 'still': 214, 'hilarious': 3, 'so': 630, 'ok literally': 1, 'never': 137, 'about': 380, 'that': 1020, 'account': 12, 'love': 198, 'it answer': 1, 'me': 800, 'this': 559, 'fellow': 3, 'apple': 13, 'peoples': 6, 'how': 293, 'many': 77, 'times': 40, 'in': 1124, 'the': 2769, 'past': 16, 'year': 72, 'have': 698, 'used': 37, 'escape': 13, 'key about': 1, '50': 6, 'today': 95, 'terminal': 1, 'vim': 3, 'user seems': 1, 'major': 12, 'complaints': 4, 'far': 35, 'are': 491, 'from': 251, 'users': 1, 'like': 741, 'yourself': 26, 'im': 696, 'wondering': 12, 'force': 5, 'quit': 7, 'gonna': 134, 'work cmdoptesc': 1, 'good': 250, 'available': 9, 'via': 6, 'menubar there': 1, 'was': 697, 'greasy': 1, 'kid': 22, 'at': 497, 'highline': 1, 'who': 161, 'basically': 9, 'miles': 2, 'dipped': 1, 'bucket': 2, 'of': 1068, 'ranch im': 1, 'disgusted he': 1, 'flashed': 1, 'us': 85, 'then': 178, 'we': 353, 'scored': 2, 'he': 289, 'sadly': 1, 'put': 73, 'his': 150, 'shirt': 8, 'fuckhighline what': 1, 'piece': 7, 'shit i': 4, 'killed': 20, 'mouse': 11, ' yay': 6, 'great': 80, 'hunter': 7, 'ive': 129, 'lots': 22, 'lizards': 4, 'bugs': 4, 'mouse i': 4, 'dont': 460, 'know': 390, 'what': 343, 'thinking': 54, 'why': 163, 'come': 122, 'into': 63, 'house': 50, 'with': 526, 'ferocious': 4, 'felines and': 2, 'had': 184, 'nerve': 2, 'to': 2543, 'try': 60, 'eat': 30, 'our': 75, 'kibble': 2, 'let': 77, 'be': 761, 'lesson': 4, 'fur': 4, 'all': 363, 'other': 97, 'mousies': 2, ' what': 23, 'day': 171, 'coming': 53, 'effie tomorrow im': 2, 'leaving': 15, 'once': 36, 'off': 147, 'work make': 2, 'sure': 111, 'bed': 28, 'seat': 8, 'saved': 7, 'next': 95, 'you avi': 1, 'hey': 12, 'boo wassup': 2, 'shorty': 4, ' youre': 11, 'beautiful': 18, 'ma': 2, ' appreciate': 2, 'too': 263, ' does': 5, 'anyone': 45, 'white': 37, 'spandex yea bet': 1, 'lemme': 5, 'borrow': 4, 'them gotchu whats': 1, 'fooly': 1, 'been': 197, 'doing good': 2, 'wby working': 1, 'than': 120, 'living': 16, 'life': 57, 'kno': 8, 'goes': 29, ' thats': 17, 'wassup': 6, ' my': 17, 'take': 101, 'new': 100, 'rule': 5, 'doesnt': 71, 'go': 258, 'enough': 38, 'cup': 8, 'drivers': 6, 'will': 236, 'dominate': 3, 'nxs': 2, 'happy': 49, 'they': 415, 'out': 355, 'for': 951, 'chase': 2, 'races': 5, 'smallvictories and': 2, 'dash': 3, 'cash': 4, 'too yes': 3, 'although': 8, 'most': 39, 'or': 339, 'some': 208, 'those': 65, 'standalones': 2, 'anyway do': 2, 'think': 265, 'wouldve': 15, 'happened': 25, 'anyway': 9, 'if': 360, 'it': 1178, 'another': 43, 'driver': 13, 'stinkin': 2, 'kyle': 3, 'has': 130, 'recently ernie': 1, 'lost': 33, 'bit': 24, 'my': 1085, 'respect': 15, 'just': 658, 'guy': 27, 'gets': 33, 'nope what': 1, 'these': 53, 'niggas': 9, 'say kennys': 1, 'black': 26, 'not': 558, 'him': 109, 'ernie': 1, 'joins': 1, 'id': 74, 'time': 242, 'stand': 18, 'together': 33, 'well': 105, 'perfect': 8, 'kneel kennys': 1, 'wife': 6, 'top': 31, 'tell': 82, 'flag': 1, 'over': 118, 'color': 5, 'your': 409, 'skin ill': 1, 'cute': 28, 'weeks u': 1, 'now ': 2, 'irs any': 1, 'hot': 22, 'chicks': 2, 'wanna': 90, 'touch': 15, 'their': 132, 'today i': 4, 'got': 317, 'u i': 2, 'havent': 62, 'groped': 1, 'ass': 92, 'while': 48, 'need': 207, 'dat lmfao so': 1, 'much': 168, 'do': 417, 'before': 74, 'dc': 1, 'ahhh i': 1, 'stuff': 42, 'here like': 1, 'forget': 21, 'pack': 4, 'something white': 1, 'girls': 26, 'singing': 8, 'niggers': 3, 'stealing': 3, 'shouldnt': 19, 'face': 28, 'any': 79, 'repercussions': 5, ' nope': 6, 'bc': 62, 'evidently': 3, 'famous': 6, 'vine': 5, 'repeated': 3, 'there': 222, 'no': 271, 'malicious': 6, 'intent': 4, 'freaking': 10, 'jokes theyre': 3, 'olds': 3, 'them': 180, 'repeating': 4, 'heard': 42, 'isnt': 75, 'an': 203, 'excuse': 8, 'does': 61, 'm ...
#
# Всего уникальных слов: 96758
